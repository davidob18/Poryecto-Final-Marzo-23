# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df_chris_yanet = pd.read_csv('./data_total.csv')
df_norma_adrian = pd.read_csv('./data_norma_adrian.csv')
df_jessica_carlos = pd.read_csv('./data_jessica_carlos.csv')

# %%
df_chris_yanet.shape
# Out:
# (1715, 15)

# %%
df_norma_adrian.shape
# Out:
# (1867, 15)

# %%
df_jessica_carlos.shape
# Out:
# (1521, 15)

# %%
data_ventas_total = pd.concat([df_chris_yanet,df_jessica_carlos,df_norma_adrian])

# %%
data_ventas_total.shape
# Out:
# (5103, 15)

# %%
data_ventas_total.to_csv('data_ventas_total.csv', index=False, encoding='utf-8')

# %%
data_ventas_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5103 entries, 0 to 1866
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   creado                    5103 non-null   object
#  1   fecha                     5103 non-null   object
#  2   proyecto                  5103 non-null   object
#  3   vendedor                  5103 non-null   object
#  4   tipo_de_cliente           5103 non-null   object
#  5   cliente                   5103 non-null   object
#  6   cantidad                  5103 non-null   float64
#  7   articulo                  5103 non-null   object
#  8   costo                     5103 non-null   float64
#  9   impresión                 5103 non-null   float64
#  10  precio                    5103 non-null   float64
#  11  total                     5103 non-null   float64
#  12  mermas                    5103 non-null   float64
# ...

# %%
data_ventas_total.describe()
# Out:
#             cantidad         costo    impresión        precio         total  \
# count    5103.000000   5103.000000  5103.000000   5103.000000  5.103000e+03
# mean     1201.567509    117.235975     6.754273    171.279558  1.848326e+04
# std      8764.563717    600.882512    17.121733    795.427933  5.130784e+04
# min         1.000000      0.000000     0.000000      0.000000  0.000000e+00
# 25%        50.000000      8.322500     0.000000     15.780000  3.071000e+03
# 50%       172.000000     27.000000     1.750000     46.190000  6.900000e+03
# 75%       500.000000     75.975000     6.670000    126.190000  1.690979e+04
# max    288000.000000  19000.000000   333.330000  19680.000000  1.574400e+06
#
#             mermas  paqueteria_o_gasto_extra  utilidad_real
# count  5103.000000               5103.000000   5.103000e+03
# mean      1.681364                 35.956334   5.351855e+03
# std       3.100116                649.580451   3.299027e+04
# ...

# %%
df_data.shape
# Out:
# (5103, 17)

# %%
data_ventas_total.utilidad_real.max()
# Out:
# 1544320.0

# %%
data_ventas_total.sort_values('utilidad_real', ascending=False).head(10)
# Out:
#                    creado       fecha       proyecto        vendedor  \
# 20    2018-11-07 12:46:07  2018-10-11   PB1810110101  JESSICA OSORIO
# 21    2018-11-07 12:46:07  2018-10-11   PB1810110101  JESSICA OSORIO
# 1629  2022-08-25 11:59:30  2022-11-30  PD20221208020    YANET FLORES
# 1241  2019-12-10 09:54:26  2021-04-30  PD20210429011    YANET FLORES
# 891   2019-01-16 18:04:56  2019-01-16   PD1811120507    YANET FLORES
# 982   2018-11-07 19:12:42  2018-10-12   PK1809120406   CARLOS ACOSTA
# 994   2018-12-07 10:23:08  2018-11-20   PK1809120406   CARLOS ACOSTA
# 1628  2022-08-25 11:59:30  2022-11-30  PD20221208010    YANET FLORES
# 1117  2019-10-08 13:23:44  2020-01-23   PD1912200107    YANET FLORES
# 1579  2022-08-25 11:59:30  2022-09-26  PD20220825024    YANET FLORES
#
#      tipo_de_cliente              cliente  cantidad  \
# 20        RECURRENTE                EXCEL      80.0
# 21        RECURRENTE                EXCEL      80.0
# ...

# %%
lista_articulos_m_vendidos = list(data_ventas_total.sort_values('utilidad_real', ascending=False).head(100).articulo)

# %%
lista_articulos_m_vendidos
# Out:
# ['PLAYERA',
#  'PANTALON',
#  'MOCHILA AUNAT POLIESTER COLOR NEGRO',
#  'PARAGUAS DE BOLSILLO',
#  'PLAYERAS',
#  'MAUSED PAD',
#  'MAUSE PAD COMPLEMENTO',
#  'MOCHILA AUNAT POLIESTER COLOR NEGRO',
#  'PARAGUAS',
#  'PLAYERA POLO 100% POLIESTER ROJA Y GRIS TALLAS S, M, X, XL',
#  'MOCHILA CON BOLSA PRINCIPAL Y FRONTAL. DOS BOLSAS LATERALES. ESPACIO PARA LAPTOP. MATERIAL:\xa0ALGODÓN / CANVAS.\xa0MEDIDAS: 32 x 39 x 14 cm.\xa0COLOR: VERDE.',
#  'CUBREBOCAS',
#  'MOCHILAS',
#  'MOCHILA',
#  'BANDERINES',
#  'CUBREBOCAS',
#  'SET PRINCE',
#  'CUBREBOCAS',
#  'MOCHILAS',
#  'MOCHILA AUNAT POLIESTER COLOR NEGRO',
#  'CUBREBOCAS',
#  'CUBREBOCAS',
#  'CUBREBOCAS',
#  'POWER BANK',
#  'CUBREBOCAS KN95',
#  'POWER',
#  'PAÑALERA',
#  'KIT',
#  'TERMÓMETROS',
#  'MOCHILAS',
#  'BATAS',
#  'PELOTAS ANTIESTRES',
#  'BOLSA ECOLÓGICA LAMINADA Y TERMO SELLADA DE NON WOVEN',
#  'BOLSAS',
#  'MOCHILAS',
#  'TERMOS',
#  'CUBREBOCAS',
#  'CILINDROS BAMBOO',
#  'DIPTICOS',
#  'CUBO ANTIESTRES',
# ...

# %% [markdown]
# # Clientes con mayor aportacion en terminos de utilidad

# %%
data_ventas_total.groupby('cliente').sum().sort_values(by=['utilidad_real'], ascending=False).head(50)
# Out:
#                                  cantidad       costo  impresión    precio  \
# cliente
# EXCEL                               200.0    599.6000    487.990  39526.39
# VIDANTA                           34360.0  14044.4700   1164.750  23906.32
# SON´S                            160528.0   6960.7300    122.420   8879.21
# GRUPO XCARET                      21204.0    285.8300     57.000    348.00
# PILGRIMS                         899698.0   3933.6200     98.950   6478.41
# HYUNDAI                           27836.0  62685.3000    366.030  67136.45
# EQF                               94526.0   5223.4350    441.150   8037.85
# INAI                              58121.0   6045.9830    496.620  10648.40
# EXPERIENCIAS XCARET               31631.0   8509.7700     36.080   8821.58
# ANDRE PRODUCTOS                  683200.0      3.6720      0.000      8.45
# QUIMICA SONS                      40535.0   8284.2000    110.200  10048.81
# ...

# %%
#df_total.groupby('cliente').sum().sort_values(by=['utilidad_real'], ascending=False).head(50)

# %%
data_ventas_total[data_ventas_total.fecha.between('2020-01-01', '2020-01-08')].head(10)
# Out:
#                    creado       fecha      proyecto            vendedor  \
# 311   2019-12-10 10:29:19  2020-01-07  PS2001030101  CRISTIAN HERNANDEZ
# 312   2019-12-10 10:29:19  2020-01-07  PS2001030101  CRISTIAN HERNANDEZ
# 1105  2019-10-08 13:23:44  2020-01-08  PD2001080201        YANET FLORES
# 353   2019-12-10 09:39:52  2020-01-03  PB2001020103      JESSICA OSORIO
# 354   2019-12-10 09:39:52  2020-01-03  PB2001020103      JESSICA OSORIO
# 355   2019-12-10 09:39:52  2020-01-03  PB2001020103      JESSICA OSORIO
# 356   2019-12-10 09:39:52  2020-01-03  PB2001020103      JESSICA OSORIO
# 357   2019-12-10 09:39:52  2020-01-03  PB2001020103      JESSICA OSORIO
# 358   2019-12-10 09:39:52  2020-01-03  PB2001030101      JESSICA OSORIO
# 359   2019-12-10 09:39:52  2020-01-03  PB2001030101      JESSICA OSORIO
#
#      tipo_de_cliente         cliente  cantidad               articulo  costo  \
# 311       RECURRENTE   SERGIO ZAMORA      50.0   HIELERA PUBLICITARIA  35.70
# ...

# %% [markdown]
# # Ventas por año

# %%
df_total_2018 = data_ventas_total[data_ventas_total.fecha.between('2018-01-01', '2018-12-31')]
df_total_2019 = data_ventas_total[data_ventas_total.fecha.between('2019-01-01', '2019-12-31')]
df_total_2020 = data_ventas_total[data_ventas_total.fecha.between('2020-01-01', '2020-12-31')]
df_total_2021 = data_ventas_total[data_ventas_total.fecha.between('2021-01-01', '2021-12-31')]
df_total_2022 = data_ventas_total[data_ventas_total.fecha.between('2022-01-01', '2022-12-31')]
df_total_2023 = data_ventas_total[data_ventas_total.fecha.between('2023-01-01', '2023-12-31')]

# %%
df_total_2018.groupby('cliente').sum().sort_values(by=['utilidad_real'], ascending=False).head(5)
# Out:
#            cantidad    costo  impresión    precio      total  mermas  \
# cliente
# EXCEL         200.0   599.60     487.99  39526.39  3132831.8     0.0
# ALEAA       80000.0    11.05       0.00     19.84   793600.0     0.0
# SON`S       17000.0   578.22      10.25    677.82   570525.0    34.0
# PATRIA RE    2100.0  1043.55      17.50   1331.13   340083.0     7.0
# GANDHI       1000.0    89.25       1.50    139.78   139780.0     0.0
#
#            paqueteria_o_gasto_extra  utilidad_real
# cliente
# EXCEL                           0.0     3063812.60
# ALEAA                           0.0      351600.00
# SON`S                           0.0       83889.22
# PATRIA RE                    1740.0       68826.45
# GANDHI                          0.0       49030.00

# %%
df_total_2019.groupby('cliente').sum().sort_values(by=['utilidad_real'], ascending=False).head(5)
# Out:
#                    cantidad     costo  impresión   precio       total  mermas  \
# cliente
# VIDANTA             12091.0  4013.740     515.12  7078.08   928864.98   204.0
# SON´S               87005.0  5012.280      33.77  6115.30  1759384.00   164.0
# INAI                39480.0  2060.078     237.30  4035.79  1052523.18   164.0
# FERRERO DE MÉXICO   23000.0    18.500       1.15    28.81   662630.00     0.0
# UNIDEP             192080.0   180.020      11.10   234.07   900363.00    41.0
#
#                    paqueteria_o_gasto_extra  utilidad_real
# cliente
# VIDANTA                               390.0     332287.460
# SON´S                                   0.0     318273.850
# INAI                                    0.0     215389.356
# FERRERO DE MÉXICO                       0.0     210680.000
# UNIDEP                                  0.0     197072.950

# %%
df_total_2020.groupby('cliente').sum().sort_values(by=['utilidad_real'], ascending=False).head(5)
# Out:
#           cantidad      costo  impresión    precio       total  mermas  \
# cliente
# EQF        50419.0   4752.325     346.52   7154.47  1461972.26   148.0
# AMERICAN   10100.0   1483.500      25.60   2356.95   861210.00    21.0
# SON´S      27823.0   1512.240      46.70   2064.90  1188968.62    98.0
# ANDRE     140000.0      8.640       0.00     12.50   570000.00     0.0
# INFOCDMX   24975.0  15255.533     284.72  23056.97   651245.06   125.0
#
#           paqueteria_o_gasto_extra  utilidad_real
# cliente
# EQF                          58.00     341405.345
# AMERICAN                      0.00     322742.130
# SON´S                      1184.61     294820.380
# ANDRE                         0.00     201600.000
# INFOCDMX                      0.00     175427.556

# %%
df_total_2021.groupby('cliente').sum().sort_values(by=['utilidad_real'], ascending=False).head(5)
# Out:
#                      cantidad     costo  impresión    precio      total  \
# cliente
# EXPERIENCIAS XCARET    9500.0    289.05       4.60    430.32  1022010.0
# SON´S                 45700.0    436.21      41.95    699.01   845941.0
# QUIMICA SONS          20106.0   3247.47      63.00   4362.28   963865.0
# ANDRE PRODUCTOS      229200.0      1.76       0.00      3.62   417984.0
# HYUNDAI                9654.0  33779.96     103.11  32630.65   800248.9
#
#                      mermas  paqueteria_o_gasto_extra  utilidad_real
# cliente
# EXPERIENCIAS XCARET    25.0                   16114.0      334197.25
# SON´S                 143.0                    2995.0      257049.06
# QUIMICA SONS           98.0                       0.0      246532.95
# ANDRE PRODUCTOS         0.0                       0.0      214992.00
# HYUNDAI                41.0                       0.0      208413.57

# %%
df_total_2022.groupby('cliente').sum().sort_values(by=['utilidad_real'], ascending=False).head(5)
# Out:
#               cantidad      costo  impresión    precio       total  mermas  \
# cliente
# GRUPO XCARET   16004.0    284.700      57.00    346.50  1848000.00     0.0
# VIDANTA        13471.0   5490.890     282.41   9357.75  1337126.10    39.0
# PILGRIMS      228501.0   3857.490      87.30   6345.18  1498764.40    13.0
# HYUNDAI         9734.0  26234.010      79.02  30568.93  1144714.20    61.0
# INAI           18342.0   3002.225     259.32   5002.69   930217.86   102.0
#
#               paqueteria_o_gasto_extra  utilidad_real
# cliente
# GRUPO XCARET                   47700.0     776000.600
# VIDANTA                          160.0     529284.900
# PILGRIMS                        6150.0     450518.710
# HYUNDAI                            0.0     309057.940
# INAI                               0.0     280824.245

# %%
df_total_2023.groupby('cliente').sum().sort_values(by=['utilidad_real'], ascending=False).head(5)
# Out:
#               cantidad     costo  impresión    precio      total  mermas  \
# cliente
# PILGRIMS       41197.0     72.18      11.65    128.33  427991.30     0.0
# HYUNDAI         7117.0   1996.83     165.91   2849.25  542801.14    23.0
# QUIMICA SONS    7515.0   1526.33       7.00   1887.13  641262.00     9.0
# NH HOTELES      6701.0  14580.53       9.45  14731.27  314000.00     0.0
# EQF            31783.0    297.54      68.75    587.84  394913.60    20.0
#
#               paqueteria_o_gasto_extra  utilidad_real
# cliente
# PILGRIMS                           0.0      151397.10
# HYUNDAI                            0.0      147268.49
# QUIMICA SONS                       0.0      128032.00
# NH HOTELES                         0.0      112536.00
# EQF                                0.0      106459.19

# %%
data_ventas_total['inversion'] = data_ventas_total.total - data_ventas_total.utilidad_real

# %%
data_ventas_total['utilidad_real/cantidad'] = (data_ventas_total.utilidad_real)/ (data_ventas_total.cantidad)

# %%
data_ventas_total.to_csv('data_ventas_total_inversion.csv', index=False, encoding='utf-8')

# %% [markdown]
# # imprimiendo por año utilidad

# %%
import seaborn as sns

# %%
df_data = data_ventas_total.copy()

# %%
df_data = df_data[df_data.fecha.between('2019-01-01', '2023-06-01')]

# %%
df_data['fecha'] = df_data.fecha.astype('datetime64[D]')
df_data['creado'] = df_data.creado.astype('datetime64[D]')
# Out:
# C:\Users\sistemas\AppData\Local\Temp\ipykernel_27776\1430661362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['fecha'] = df_data.fecha.astype('datetime64[D]')
# C:\Users\sistemas\AppData\Local\Temp\ipykernel_27776\1430661362.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['creado'] = df_data.creado.astype('datetime64[D]')

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4833 entries, 54 to 1866
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   creado                    4833 non-null   datetime64[ns]
#  1   fecha                     4833 non-null   datetime64[ns]
#  2   proyecto                  4833 non-null   object
#  3   vendedor                  4833 non-null   object
#  4   tipo_de_cliente           4833 non-null   object
#  5   cliente                   4833 non-null   object
#  6   cantidad                  4833 non-null   float64
#  7   articulo                  4833 non-null   object
#  8   costo                     4833 non-null   float64
#  9   impresión                 4833 non-null   float64
#  10  precio                    4833 non-null   float64
#  11  total                     4833 non-null   float64
#  12  mermas                    4833 non-null   float64
# ...

# %%
df_data_ventas_anio['anio'] = df_data_ventas_anio.fecha.dt.year
df_data_ventas_anio['mes'] = df_data_ventas_anio.fecha.dt.month
df_data_ventas_anio['dia'] = df_data_ventas_anio.fecha.dt.day

# %%
df_data_ventas_anio.head(2)
# Out:
#        fecha  cantidad   costo  impresión  precio    total  mermas  \
# 0 2019-01-04     300.0   15.00       0.00   18.60   5580.0     0.0
# 1 2019-01-07    2170.0  306.13      14.29  475.84  57025.5     5.0
#
#    paqueteria_o_gasto_extra  utilidad_real  anio  mes  dia
# 0                       0.0        1080.00  2019    1    4
# 1                       0.0       15466.92  2019    1    7

# %%
mes = ['Enero', 'Frebrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre','Octumbre', 'Noviembre', 'Diciembre']

# %%
plt.figure(figsize=(15,8))

#sns.lineplot(df_data_ventas_anio['mes'], df_data_ventas_anio['utilidad_real'], hue = df_data_ventas_anio['anio'])
#sns.lineplot(df_data_ventas_anio['mes'], df_data_ventas_anio['utilidad_real'], hue = df_data_ventas_anio['anio'])
sns.lineplot(data=df_data_ventas_anio, x='mes', y='utilidad_real', hue = 'anio')

#plt.xticks(range(1,13), labels = [f'mes_{i}' for i in range(1, 13)])
plt.xticks(range(1,13), labels = mes)

plt.grid()
plt.show()

# %%
df_data_ventas_anio = df_data.groupby('fecha').sum()

# %%
df_data_ventas_anio.reset_index(inplace=True)

# %%
df_data_ventas_anio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880 entries, 0 to 879
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   fecha                     880 non-null    datetime64[ns]
#  1   cantidad                  880 non-null    float64
#  2   costo                     880 non-null    float64
#  3   impresión                 880 non-null    float64
#  4   precio                    880 non-null    float64
#  5   total                     880 non-null    float64
#  6   mermas                    880 non-null    float64
#  7   paqueteria_o_gasto_extra  880 non-null    float64
#  8   utilidad_real             880 non-null    float64
#  9   anio                      880 non-null    int64
#  10  mes                       880 non-null    int64
#  11  dia                       880 non-null    int64
# dtypes: datetime64[ns](1), float64(8), int64(3)
# memory usage: 82.6 KB

# %%
df_data = pd.

# %%
df_data = pd.read_csv('./data_ventas_total_inversion.csv')

# %%
df_data.groupby('cliente').proyecto.nunique()
# Out:
# cliente
# 3.1416R                             2
# A3SEC                               1
# A3SEC SA DE CV                      1
# AARALI                              1
# ABAMTR                              1
#                                    ..
# ostar                               1
# proyectoapro                        1
# sevmexico                           1
# suministros de computo y oficina    1
# tedaural                            1
# Name: proyecto, Length: 1069, dtype: int64

# %%
df_data.groupby('cliente').sum()
# Out:
#                                   cantidad     costo  impresión   precio  \
# cliente
# 3.1416R                              190.0   339.240      35.19   561.92
# A3SEC                                500.0     3.780       1.85    12.39
# A3SEC SA DE CV                       100.0   138.840      28.80   234.70
# AARALI                               100.0    13.010       0.00    33.18
# ABAMTR                                50.0    43.120      14.80    86.76
# ...                                    ...       ...        ...      ...
# ostar                                 51.0     0.000       0.00     0.00
# proyectoapro                         300.0    32.045       5.34    64.89
# sevmexico                            300.0     4.920       0.00     5.90
# suministros de computo y oficina      50.0    23.040       0.00    35.71
# tedaural                             241.0  1564.600       0.00  1578.81
#
#                                     total  mermas  paqueteria_o_gasto_extra  \
# ...

# %%
df_data_art = df_data.copy()

# %%
df_data_art['llavero'] = (df_data_art.apply(lambda row: row.astype(str).str.lower().str.contains('llave').any(), axis=1)).astype(int)

# %%
df_data_art.head(1)
# Out:
#                 creado       fecha      proyecto            vendedor  \
# 0  2018-10-29 10:15:30  2018-10-01  PS1808080202  CRISTIAN HERNANDEZ
#
#   tipo_de_cliente cliente  cantidad articulo  costo  impresión  precio  \
# 0      RECURRENTE   VMACS      10.0  HIELERA  88.07        0.0  140.91
#
#     total  mermas  paqueteria_o_gasto_extra  utilidad_real  inversion  \
# 0  1409.1     0.0                       0.0          528.4      880.7
#
#    utilidad_real/cantidad  llavero
# 0                   52.84        0

# %%
df_data_art[df_data_art.llavero==1].head(2)
# Out:
#                  creado       fecha      proyecto            vendedor  \
# 49  2018-12-13 10:46:15  2018-12-13  AS1812110101  CRISTIAN HERNANDEZ
# 57  2019-01-31 11:45:04  2019-01-28  AS1901250302  CRISTIAN HERNANDEZ
#
#    tipo_de_cliente      cliente  cantidad                    articulo  costo  \
# 49      RECURRENTE  ALTECH CORP     500.0          LLAVERO FLEXOMETRO   4.94
# 57           NUEVO      ADHETEC     200.0  CARRIE Llavero de plástico   4.80
#
#     impresión  precio   total  mermas  paqueteria_o_gasto_extra  \
# 49        1.1    8.58  4290.0     2.0                      98.5
# 57        2.2   15.50  3100.0     2.0                       0.0
#
#     utilidad_real  inversion  utilidad_real/cantidad  llavero
# 49        1161.62    3128.38                 2.32324        1
# 57        1690.40    1409.60                 8.45200        1

# %%
df_data_art[df_data_art.llavero==1].shape
# Out:
# (163, 18)

# %% [markdown]
# # inversion (costo)

# %%
df_total_inversion = df_total[['fecha']]

# %%
df_total_inversion['iversion'] = df_total.total - df_total.utilidad_real
# Out:
# C:\Users\sistemas\AppData\Local\Temp\ipykernel_16896\1837482621.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_inversion['iversion'] = df_total.total - df_total.utilidad_real

# %%
df_total_inversion_time = df_total_inversion.groupby('fecha').sum()

# %%
df_total_inversion.sort_values(by='fecha').head(10)
# Out:
#           fecha  iversion
# 0    2018-10-01    880.70
# 1    2018-10-01   4513.30
# 2    2018-10-01   2281.30
# 3    2018-10-01    863.20
# 5    2018-10-01   6742.40
# 6    2018-10-01   8975.08
# 4    2018-10-02   1493.88
# 846  2018-10-04    923.00
# 847  2018-10-04   5894.60
# 848  2018-10-04   9329.92

# %%
df_total_inversion_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 592 entries, 2018-10-01 to 2023-03-08
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   iversion  592 non-null    float64
# dtypes: float64(1)
# memory usage: 9.2+ KB

# %%
df_total_inversion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1715 entries, 0 to 1714
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fecha     1715 non-null   datetime64[ns]
#  1   iversion  1715 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 26.9 KB

# %%
df_total_inversion['fecha'] = df_total_inversion.fecha.astype('datetime64[D]')
# Out:
# C:\Users\sistemas\AppData\Local\Temp\ipykernel_16896\3690077023.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_total_inversion['fecha'] = df_total_inversion.fecha.astype('datetime64[D]')

# %%
import matplotlib

matplotlib.rcParams['figure.figsize'] = (10, 8)

# %%
df_total_inversion_time.resample('Y').sum().plot()
# Out:
# <AxesSubplot:xlabel='fecha'>

# %%
df_total_inversion_time.resample('Y').sum()
# Out:
#                iversion
# fecha
# 2018-12-31   712393.370
# 2019-12-31  4775790.600
# 2020-12-31  2536253.174
# 2021-12-31  3824985.242
# 2022-12-31  6569083.521
# 2023-12-31   602971.880

# %%
lista_articulos = list(df_total.articulo)

# %%
a = 'TERMO DOBLE PARED. PARED INTERNA DE PLÁSTICO Y'

# %%
a_2 = a.split()
a_2
# Out:
# ['TERMO', 'DOBLE', 'PARED.', 'PARED', 'INTERNA', 'DE', 'PLÁSTICO', 'Y']

# %%
def word_pattern(a_2):
    ret,  box, i = [], {}, 1
    for e in a_2:
        e = e.lower().replace('(.*','').replace('.','').replace(':','').strip()
        if e in box:
            i=int(box[e])
            box[e]=i+1
        if e not in box:
            box[e]=str(i)
    return box

# %%
for oracion in lista_articulos:
    palabra = oracion.split()
    for e in palabra:
        e = e.lower().replace('(.*','').replace('.','').replace(':','').strip()
        if e in box:
            i=int(box[e])
            box[e]=i+1
        if e not in box:
            box[e]=str(i)

# %%
data_palabras = pd.DataFrame.from_dict(box, orient='index')

# %%
data_palabras=data_palabras.reset_index()
data_palabras
# Out:
#          index    0
# 0        termo   71
# 1        doble   48
# 2        pared   59
# 3      interna    2
# 4           de  595
# ...        ...  ...
# 1098   cosida,  107
# 1099      asas   69
# 1100  amarillo   64
# 1101        90  189
# 1102   rayadas    2
#
# [1103 rows x 2 columns]

# %%
data_palabras.columns = ['palabra','repeticion']

# %%
data_palabras.head(5)
# Out:
#    palabra repeticion
# 0    termo         71
# 1    doble         48
# 2    pared         59
# 3  interna          2
# 4       de        595

# %%
data_palabras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1103 entries, 0 to 1102
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   palabra     1103 non-null   object
#  1   repeticion  1103 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 17.4+ KB

# %%
data_palabras['repeticion'] = data_palabras.repeticion.astype('int64')

# %%
data_palabras.sort_values(by='repeticion', ascending=False).head(10)
# Out:
#          palabra  repeticion
# 4             de         595
# 1090       trigo         583
# 1089       fibra         582
# 1085  terciopelo         579
# 1074  cumpleaños         574
# 1075   sulfatada         574
# 1053        mano         543
# 1043  tequileros         533
# 1042       costo         532
# 1033      cables         529

# %%
global lista_num
lista_num=[]

def capturar_articulo(num):
    
    
    num= str(num)
    #print(type(num))
    if 'termo' in num:
        lista_num.append(num)
        #num = float(num)
        return num
    
    
    else:
        #num = float(num)
        return num

# %%
data_palabras.palabra.apply(capturar_articulo)
# Out:
# 0          termo
# 1          doble
# 2          pared
# 3        interna
# 4             de
#           ...
# 1098     cosida,
# 1099        asas
# 1100    amarillo
# 1101          90
# 1102     rayadas
# Name: palabra, Length: 1103, dtype: object

# %%
lista_num
# Out:
# ['portegafetes', 'portagafetes', 'gafetes']

# %%
lista_num
# Out:
# ['mochila', 'mochilas', 'bolsa-mochila']

# %%
lista_num
# Out:
# ['termo', 'termos', 'termosellada', 'termo', 'termos', 'termosellada']

# %%
df_total_2018[['articulo']].contains('HIEL')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16896\1664818459.py in <module>
# ----> 1 df_total_2018[['articulo']].contains('HIEL')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'contains'

# %%
df_total_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 0 to 888
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   creado                    99 non-null     object
#  1   fecha                     99 non-null     object
#  2   proyecto                  99 non-null     object
#  3   vendedor                  99 non-null     object
#  4   tipo_de_cliente           99 non-null     object
#  5   cliente                   99 non-null     object
#  6   cantidad                  99 non-null     float64
#  7   articulo                  99 non-null     object
#  8   costo                     99 non-null     float64
#  9   impresión                 99 non-null     float64
#  10  precio                    99 non-null     float64
#  11  total                     99 non-null     float64
#  12  mermas                    99 non-null     float64
# ...

# %%
type(df_total_2018['articulo'].squeeze())
# Out:
# pandas.core.series.Series

# %%
type(df_total_2018)
# Out:
# pandas.core.frame.DataFrame

# %%
df_total_2018.apply(lambda row: row.astype(str).str.lower().str.contains('tequ').any(), axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 884    False
# 885    False
# 886    False
# 887    False
# 888    False
# Length: 99, dtype: bool

# %%
df_total_2018[df_total_2018.apply(lambda row: row.astype(str).str.lower().str.contains('por').any(), axis=1)]
# Out:
#                  creado       fecha      proyecto            vendedor  \
# 3   2018-11-07 09:04:28  2018-10-01  PS1808080202  CRISTIAN HERNANDEZ
# 11  2018-11-07 09:54:05  2018-10-18  AS1810160201  CRISTIAN HERNANDEZ
# 13  2018-11-07 10:04:00  2018-10-24  AS1809180506  CRISTIAN HERNANDEZ
# 14  2018-11-07 10:04:00  2018-10-24  AS1809180506  CRISTIAN HERNANDEZ
# 42  2018-11-29 15:25:32  2018-11-28  PS1811120101  CRISTIAN HERNANDEZ
#
#    tipo_de_cliente cliente  cantidad               articulo  costo  impresión  \
# 3       RECURRENTE   VMACS      10.0        PORTA PASAPORTE  86.32        0.0
# 11           NUEVO  RIONMA      20.0  PORTARRETRATO GIRABLE  75.07       44.0
# 13           NUEVO  YAKULT    1000.0           PORTEGAFETES   7.14        0.0
# 14           NUEVO  YAKULT    1000.0       MICA PORTAGAFETE   2.20        0.0
# 42      RECURRENTE  SINTRA     100.0           PORTA GAFETE  15.18        0.0
#
#     precio   total  mermas  paqueteria_o_gasto_extra  utilidad_real
# ...

# %%
df_total_2018[['articulo']].apply(lambda row: row.astype(str).str.lower().str.contains('por').any(), axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 884    False
# 885    False
# 886    False
# 887    False
# 888    False
# Length: 99, dtype: bool

# %%
int(False)
# Out:
# 0

# %%
int(True)
# Out:
# 1

# %%
data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains('term').any(), axis=1)]
# Out:
#            palabra  repeticion
# 0            termo          71
# 165        termico           4
# 432        termica          15
# 641         termos          38
# 1017  termosellada          21
# 1028     terminado          14

# %%
data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains('taz').any(), axis=1)]
# Out:
#     palabra  repeticion
# 116    taza          50
# 577   tazas          73
# 727  tazasa           7

# %%
data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains('boli').any(), axis=1)]
# Out:
#         palabra  repeticion
# 24    boligrafo          72
# 232  boligrafos          44
# 574   futbolito           9

# %%
data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains('porta').any(), axis=1)]
# Out:
#              palabra  repeticion
# 12             porta          53
# 26     portarretrato           2
# 32       portagafete           9
# 242     portagafetes          10
# 267     portalápices           2
# 438         portatil          31
# 504  portadocumentos          24
# 682       portavasos          10
# 800       portafolio          15
# 973         portable         228

# %%
data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains('libre').any(), axis=1)]
# Out:
#       palabra  repeticion
# 65   libretas          20
# 82    libreta          37
# 831    libres          92

# %%
data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains('humi').any(), axis=1)]
# Out:
#             palabra  repeticion
# 1021  humidificador         514

# %%
data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains('pelo').any(), axis=1)]
# Out:
#          palabra  repeticion
# 39        pelota          16
# 573      pelotas          15
# 575      pelotan          29
# 1085  terciopelo         579

# %%
data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains('anti').any(), axis=1)]
# Out:
#            palabra  repeticion
# 33      antiestres          21
# 290    anti-stress           8
# 338     antiviento           5
# 341  antibacterial          16
# 391           anti           4
# 423     antiventos           6
# 576    anti-estres          29
# 700      antirrobo           7
# 767        antifaz          14
# 810     antiestrés          16
# 860     diamantina         353

# %%
data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains('calcu').any(), axis=1)]
# Out:
#          palabra  repeticion
# 511  calculadora         166

# %%
data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains('agend').any(), axis=1)]
# Out:
#     palabra  repeticion
# 28   agenda          17
# 74  agendas           4

# %%
data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains('moch').any(), axis=1)]
# Out:
#            palabra  repeticion
# 8          mochila          31
# 225       mochilas          13
# 243  bolsa-mochila          16

# %%
data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains('vin').any(), axis=1)]
# Out:
#      palabra  repeticion
# 71      vino          16
# 430    vinos          18
# 487  vintage          21
# 996    vinil         492

# %%
data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains('cubre').any(), axis=1)]
# Out:
#         palabra  repeticion
# 350  cubrebocas         187
# 365       cubre          24

# %%
data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains('masc').any(), axis=1)]
# Out:
# Empty DataFrame
# Columns: [palabra, repeticion]
# Index: []

# %%
promo_articulo = """Llavero
Termo
Cilindro
Taza
Vaso
Tarro
Vino
Set
Hielera
Humificado
Frazada
Juego
Guantes
Cuchara
Utensilios
Bolsa
Lonchera
Mochila
Maletin maleta
Porta
Libreta
Carpeta
Bolígrafo
Usb
Bocina
Cable
Soporte
Celular
Joyero
Toalla
Cosmetiquera
Espejo
Maleta
Tapete
Funda
Almohada
Frazada
Peluche
Anti-estress
Pelota
Navaja
Herramienta
Organizador
Parasol
Botella
Contenedor
Plato
Cuaderno
Copa
Caja
Gorra
Playera
"""

# %%
promo_articulo=list(promo_articulo.split())

# %%
data_palabras
# Out:
#        palabra  repeticion
# 0        termo          71
# 1        doble          48
# 2        pared          59
# 3      interna           2
# 4           de         595
# ...        ...         ...
# 1098   cosida,         107
# 1099      asas          69
# 1100  amarillo          64
# 1101        90         189
# 1102   rayadas           2
#
# [1103 rows x 2 columns]

# %%
promo_articulo
# Out:
# ['Llavero',
#  'Termo',
#  'Cilindro',
#  'Taza',
#  'Vaso',
#  'Tarro',
#  'Vino',
#  'Set',
#  'Hielera',
#  'Humificado',
#  'Frazada',
#  'Juego',
#  'Guantes',
#  'Cuchara',
#  'Utensilios',
#  'Bolsa',
#  'Lonchera',
#  'Mochila',
#  'Maletin',
#  'maleta',
#  'Porta',
#  'Libreta',
#  'Carpeta',
#  'Bolígrafo',
#  'Usb',
#  'Bocina',
#  'Cable',
#  'Soporte',
#  'Celular',
#  'Joyero',
#  'Toalla',
#  'Cosmetiquera',
#  'Espejo',
#  'Maleta',
#  'Tapete',
#  'Funda',
#  'Almohada',
#  'Frazada',
#  'Peluche',
#  'Anti-estress',
#  'Pelota',
#  'Navaja',
#  'Herramienta',
#  'Organizador',
#  'Parasol',
#  'Botella',
#  'Contenedor',
#  'Plato',
#  'Cuaderno',
#  'Copa',
#  'Caja',
#  'Gorra',
#  'Playera']

# %%
promo_art_2 = pd.DataFrame()

for art in promo_articulo:
    art = str(art)
    art = art.lower()
    #print(art)
    promo_art = data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains(art).any(), axis=1)]
    promo_art_2 = pd.concat([promo_art_2, promo_art])

# %%
promo_art_2.repeticion.max()
# Out:
# 529

# %%
promo_art_2[promo_art_2.palabra == 'vaso']
# Out:
#    palabra  repeticion
# 87    vaso          43

# %%
promo_art_2 = pd.DataFrame()

for art in promo_articulo:
    art = str(art)
    art = art.lower()
    #print(art)
    promo_art = data_palabras[data_palabras[['palabra']].apply(lambda row: row.astype(str).str.lower().str.contains(art).any(), axis=1)]
    promo_art_2 = pd.concat([promo_art_2, promo_art])
# Out:
#                    creado       fecha       proyecto            vendedor  \
# 0     2018-10-29 10:15:30  2018-10-01   PS1808080202  CRISTIAN HERNANDEZ
# 1     2018-11-07 09:04:28  2018-10-01   PS1808080202  CRISTIAN HERNANDEZ
# 2     2018-11-07 09:04:28  2018-10-01   PS1808080202  CRISTIAN HERNANDEZ
# 3     2018-11-07 09:04:28  2018-10-01   PS1808080202  CRISTIAN HERNANDEZ
# 4     2018-11-07 09:19:25  2018-10-02   AS1809240301  CRISTIAN HERNANDEZ
# ...                   ...         ...            ...                 ...
# 1710  2023-01-24 10:20:28  2023-03-01  PD20230209013        YANET FLORES
# 1711  2023-01-24 10:20:47  2023-03-01  PD20230209013        YANET FLORES
# 1712  2023-01-24 10:20:47  2023-03-01  PD20230209013        YANET FLORES
# 1713  2023-01-24 10:20:47  2023-03-03  PD20230220012        YANET FLORES
# 1714  2023-01-24 10:20:47  2023-03-08    PD202209081        YANET FLORES
#
#      tipo_de_cliente         cliente  cantidad  \
# ...

# %%
promo_art = df_total[['articulo']].apply(lambda row: row.astype(str).str.lower().str.contains('vaso').any(), axis=1)

# %%
promo_art
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1710    False
# 1711    False
# 1712    False
# 1713    False
# 1714    False
# Length: 1715, dtype: bool

# %%
promo_art = promo_art.astype(int)

# %%
promo_art.sum()
# Out:
# 49

# %%
promo_art = df_total[['articulo']].apply(lambda row: row.astype(str).str.lower().str.contains('vasos').any(), axis=1)

# %%
promo_art = promo_art.astype(int)

# %%
promo_art.sum()
# Out:
# 7

# %%
df_total[df_total[['articulo']].apply(lambda row: row.astype(str).str.lower().str.contains('vasos').any(), axis=1)]
# Out:
#                    creado       fecha       proyecto      vendedor  \
# 903   2019-02-15 16:36:23  2019-02-15   PD1902010202  YANET FLORES
# 969   2019-05-14 16:13:16  2019-05-15   PD1904300404  YANET FLORES
# 1100  2019-10-08 13:23:44  2019-12-06   PD1912030502  YANET FLORES
# 1126  2019-10-08 13:23:44  2020-03-03   PD2002260101  YANET FLORES
# 1152  2019-12-10 09:54:26  2020-09-09   PD2008260402  YANET FLORES
# 1224  2019-12-10 09:54:26  2021-03-24  PD20210323030  YANET FLORES
# 1227  2019-12-10 09:54:26  2021-03-25  PD20210302021  YANET FLORES
#
#      tipo_de_cliente  cliente  cantidad                    articulo  costo  \
# 903       RECURRENTE  VIDANTA     144.0           VASOS DOBLE PARED  33.44
# 969       RECURRENTE  VIDANTA     100.0   PORTAVASOS CON DESTAPADOR   5.67
# 1100      RECURRENTE  VIDANTA     100.0                 PORTA VASOS   5.50
# 1126      RECURRENTE  VIDANTA     300.0  PORTA VASOS CON DESTAPADOR   5.31
# ...

# %%
df_total[df_total[['articulo']].apply(lambda row: row.astype(str).str.lower().str.contains('vaso').any(), axis=1)]
# Out:
#                    creado       fecha       proyecto            vendedor  \
# 59    2019-02-01 17:15:02  2019-02-01   PS1901180103  CRISTIAN HERNANDEZ
# 136   2019-05-29 12:58:01  2019-05-28   AS1905280102  CRISTIAN HERNANDEZ
# 177   2019-06-26 17:23:06  2019-06-24   PS1905290104  CRISTIAN HERNANDEZ
# 191   2019-07-15 11:01:33  2019-07-15   AS1906050103  CRISTIAN HERNANDEZ
# 258   2019-10-24 18:28:12  2019-10-23   AS1909300103  CRISTIAN HERNANDEZ
# 296   2019-11-20 18:15:44  2019-11-19   AS1911040104  CRISTIAN HERNANDEZ
# 374   2019-12-10 10:29:19  2020-10-12   AS2010120101  CRISTIAN HERNANDEZ
# 401   2019-12-10 10:29:19  2020-11-26   AS2011250101  CRISTIAN HERNANDEZ
# 511   2019-12-10 10:29:19  2021-11-05  AS20211103011  CRISTIAN HERNANDEZ
# 632   2022-04-06 11:14:25  2022-06-03  AS20220601064  CRISTIAN HERNANDEZ
# 667   2022-06-29 10:07:47  2022-06-29  AS20220629010  CRISTIAN HERNANDEZ
# 719   2022-08-19 17:10:31  2022-09-01  AS20220831031  CRISTIAN HERNANDEZ
# ...
